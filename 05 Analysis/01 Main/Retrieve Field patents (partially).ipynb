# %% [markdown]
# ## This notebook retrieves patents from fields with partial call

# %%
fields =['G06F', 'B60R', 'G06K', 'E05F', 'G11B', 'G06T', 'G11C', 'G10L', 'G01J', 'H01Q', 'F16M', 'H03G', 'B29C', 'F04D', 'G08C', 'H01L', 'H04L', 'H01R', 'H05K', 'B32B', 'H04N', 'G02B', 'G06Q', 'B65H', 'H04H', 'F21V', 'E05D', 'E05C', 'H03K', 'G09G', 'G10H', 'H02J', 'F28D', 'H04Q', 'H03M', 'G06V']

import api. fetch_patents
import importlib
importlib.reload(api.fetch_patents)

list_patents = []
for field in fields:
    for year in range(1990, 2023):
        assg = api.fetch_patents.get_patents_from_fields(field = field, year = year, group_only=True, partial_call=True, source= "legacy")
        patents = assg[0][field][str(year)]['patents']

        for pat in patents:
            list_patents.append(pat)
        print(f"Field : {field}, and year : {year}")
        print(f"Size of patents: {len(list_patents)}")
# Out:
# It took 1.83 sec to retrieve patents under Partial call = True
# Field : G06F, and year : 1990
# Size of patents: 2113
# It took 1.44 sec to retrieve patents under Partial call = True
# Field : G06F, and year : 1991
# Size of patents: 4413
# It took 1.21 sec to retrieve patents under Partial call = True
# Field : G06F, and year : 1992
# Size of patents: 7301
# It took 1.56 sec to retrieve patents under Partial call = True
# Field : G06F, and year : 1993
# Size of patents: 10708
# It took 2.38 sec to retrieve patents under Partial call = True
# Field : G06F, and year : 1994
# Size of patents: 15228
# It took 1.77 sec to retrieve patents under Partial call = True
# Field : G06F, and year : 1995
# Size of patents: 21751
# It took 2.74 sec to retrieve patents under Partial call = True
# Field : G06F, and year : 1996
# Size of patents: 29297
# It took 2.50 sec to retrieve patents under Partial call = True
# Field : G06F, and year : 1997
# Size of patents: 38678
# It took 3.38 sec to retrieve patents under Partial call = True
# Field : G06F, and year : 1998
# Size of patents: 48291
# It took 4.17 sec to retrieve patents under Partial call = True
# Field : G06F, and year : 1999
# Size of patents: 58615
# It took 5.14 sec to retrieve patents under Partial call = True
# Field : G06F, and year : 2000
# Size of patents: 69920
# It took 4.88 sec to retrieve patents under Partial call = True
# Field : G06F, and year : 2001
# Size of patents: 81888
# It took 4.51 sec to retrieve patents under Partial call = True
# Field : G06F, and year : 2002
# Size of patents: 93993
# It took 5.60 sec to retrieve patents under Partial call = True
# Field : G06F, and year : 2003
# Size of patents: 107101
# It took 36.97 sec to retrieve patents under Partial call = True
# Field : G06F, and year : 2004
# Size of patents: 122036
# It took 6.08 sec to retrieve patents under Partial call = True
# Field : G06F, and year : 2005
# Size of patents: 137563
# It took 5.36 sec to retrieve patents under Partial call = True
# Field : G06F, and year : 2006
# Size of patents: 153899
# It took 6.92 sec to retrieve patents under Partial call = True
# Field : G06F, and year : 2007
# Size of patents: 171732
# It took 8.71 sec to retrieve patents under Partial call = True
# Field : G06F, and year : 2008
# Size of patents: 191744
# It took 6.11 sec to retrieve patents under Partial call = True
# Field : G06F, and year : 2009
# Size of patents: 208993
# It took 6.08 sec to retrieve patents under Partial call = True
# Field : G06F, and year : 2010
# Size of patents: 228555
# It took 9.72 sec to retrieve patents under Partial call = True
# Field : G06F, and year : 2011
# Size of patents: 250771
# It took 8.78 sec to retrieve patents under Partial call = True
# Field : G06F, and year : 2012
# Size of patents: 278280
# It took 41.88 sec to retrieve patents under Partial call = True
# Field : G06F, and year : 2013
# Size of patents: 307241
# It took 42.09 sec to retrieve patents under Partial call = True
# Field : G06F, and year : 2014
# Size of patents: 335427
# It took 12.65 sec to retrieve patents under Partial call = True
# Field : G06F, and year : 2015
# Size of patents: 364828
# It took 10.73 sec to retrieve patents under Partial call = True
# Field : G06F, and year : 2016
# Size of patents: 393982
# It took 11.48 sec to retrieve patents under Partial call = True
# Field : G06F, and year : 2017
# Size of patents: 423298
# It took 12.59 sec to retrieve patents under Partial call = True
# Field : G06F, and year : 2018
# Size of patents: 453834
# It took 21.11 sec to retrieve patents under Partial call = True
# Field : G06F, and year : 2019
# Size of patents: 487580
# It took 10.62 sec to retrieve patents under Partial call = True
# Field : G06F, and year : 2020
# Size of patents: 516377
# It took 9.20 sec to retrieve patents under Partial call = True
# Field : G06F, and year : 2021
# Size of patents: 537781
# It took 37.35 sec to retrieve patents under Partial call = True
# Field : G06F, and year : 2022
# Size of patents: 548475
# It took 29.05 sec to retrieve patents under Partial call = True
# Field : B60R, and year : 1990
# Size of patents: 549146
# It took 28.03 sec to retrieve patents under Partial call = True
# Field : B60R, and year : 1991
# Size of patents: 549820
# It took 28.22 sec to retrieve patents under Partial call = True
# Field : B60R, and year : 1992
# Size of patents: 550542
# It took 28.81 sec to retrieve patents under Partial call = True
# Field : B60R, and year : 1993
# Size of patents: 551423
# It took 28.89 sec to retrieve patents under Partial call = True
# Field : B60R, and year : 1994
# Size of patents: 552427
# It took 29.21 sec to retrieve patents under Partial call = True
# Field : B60R, and year : 1995
# Size of patents: 553671
# It took 28.73 sec to retrieve patents under Partial call = True
# Field : B60R, and year : 1996
# Size of patents: 554906
# It took 28.79 sec to retrieve patents under Partial call = True
# Field : B60R, and year : 1997
# Size of patents: 556297
# It took 31.14 sec to retrieve patents under Partial call = True
# Field : B60R, and year : 1998
# Size of patents: 557687
# It took 1.17 sec to retrieve patents under Partial call = True
# Field : B60R, and year : 1999
# Size of patents: 557688
# It took 28.41 sec to retrieve patents under Partial call = True
# Field : B60R, and year : 2000
# Size of patents: 559249
# It took 29.07 sec to retrieve patents under Partial call = True
# Field : B60R, and year : 2001
# Size of patents: 560824
# It took 28.43 sec to retrieve patents under Partial call = True
# Field : B60R, and year : 2002
# Size of patents: 562526
# It took 29.27 sec to retrieve patents under Partial call = True
# Field : B60R, and year : 2003
# Size of patents: 564182
# It took 30.07 sec to retrieve patents under Partial call = True
# Field : B60R, and year : 2004
# Size of patents: 565630
# It took 29.94 sec to retrieve patents under Partial call = True
# Field : B60R, and year : 2005
# Size of patents: 567037
# It took 29.67 sec to retrieve patents under Partial call = True
# Field : B60R, and year : 2006
# Size of patents: 568365
# It took 29.11 sec to retrieve patents under Partial call = True
# Field : B60R, and year : 2007
# Size of patents: 569596
# It took 28.59 sec to retrieve patents under Partial call = True
# Field : B60R, and year : 2008
# Size of patents: 570861
# It took 27.99 sec to retrieve patents under Partial call = True
# Field : B60R, and year : 2009
# Size of patents: 571889
# It took 28.55 sec to retrieve patents under Partial call = True
# Field : B60R, and year : 2010
# Size of patents: 572935
# It took 29.06 sec to retrieve patents under Partial call = True
# Field : B60R, and year : 2011
# Size of patents: 574070
# It took 28.87 sec to retrieve patents under Partial call = True
# Field : B60R, and year : 2012
# Size of patents: 575293
# It took 29.26 sec to retrieve patents under Partial call = True
# Field : B60R, and year : 2013
# Size of patents: 576614
# It took 28.67 sec to retrieve patents under Partial call = True
# Field : B60R, and year : 2014
# Size of patents: 578229
# NO PATENTS HERE
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 11
#       9 for year in range(1990, 2023):
#      10     assg = api.fetch_patents.get_patents_from_fields(field = field, year = year, group_only=True, partial_call=True, source= "legacy")
# ---> 11     patents = assg[0][field][str(year)]['patents']
#      13     for pat in patents:
#      14         list_patents.append(pat)
#
# TypeError: 'NoneType' object is not subscriptable
