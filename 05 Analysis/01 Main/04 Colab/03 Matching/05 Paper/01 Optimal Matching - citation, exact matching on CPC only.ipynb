# %% [markdown]
# # Drive and utilities

# %%
#@title Mount Drive to get BERT model
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
#@title Utils
# !pip install dill
# !pip install pandas
# !pip install numpy
!
import dill as pickle
# Out:
# Requirement already satisfied: dill in /usr/local/lib/python3.12/dist-packages (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (2.0.2)

# %%
#@title Clone the repo and add API key
# !git clone https://github.com/amusali/bert_for_patents.git
import os
# Api key setting
os.environ['patentsview_api_key'] = 'Uch9R1RR.BxaQcxV8HK4nBMgTTjX1F9CQW8PF4nXw'  # Replace with your actual key
# Out:
# Cloning into 'bert_for_patents'...
# remote: Enumerating objects: 1945, done.
# remote: Counting objects: 100% (203/203), done.
# remote: Compressing objects: 100% (82/82), done.
# remote: Total 1945 (delta 131), reused 175 (delta 118), pack-reused 1742 (from 2)
# Receiving objects: 100% (1945/1945), 204.93 MiB | 15.05 MiB/s, done.
# Resolving deltas: 100% (1090/1090), done.

# %%
#@title Run setup file to get environment
#!python "/content/bert_for_patents/05 Analysis/01 Main/setup_colab.py"

import sys
sys.path.append('/content/bert_for_patents/05 Analysis/01 Main')
os.chdir("/content/bert_for_patents/05 Analysis/01 Main")

# %%
#@title Pull latest changes from repo
# %cd "/content/bert_for_patents"
# !git pull origin master
#@title Add paths to the system and change directory
import sys
sys.path.append('/content/bert_for_patents/05 Analysis/01 Main')
os.chdir("/content/bert_for_patents/05 Analysis/01 Main")
# Out:
# /content/bert_for_patents
# From https://github.com/amusali/bert_for_patents
#  * branch            master     -> FETCH_HEAD
# Already up to date.

# %% [markdown]
# # Prepare

# %%
import api.matching_optimal_cit_no_exact as matching
import importlib
importlib.reload(matching)

# Prepare
# matching.prepare() - not running this since the files already exists in the folder /content/drive/MyDrive/PhD Data/11 Matches/optimization results/citation_no_exact_match_on_grantyear
# Out:
# Loaded data: 145878465 citations, 19649 treated patents, 5941114 control patents, 5805396 clean ids.
# Preprocessed data: 89274607 citations, 19649 treated patents, 5805396 control patents.
# Precompute Cosine Distances: 100%|██████████| 835/835 [09:34<00:00,  1.45it/s]
# ✅ Saved cosine for 19649 treated patents and 835 group candidate-id lists.
# Saved citation_counts_dict.
# Saved control DataFrame.
# Saved treated_counts_dict for baseline_begin_period=9 quarters.
# ⚙️ Computing Mahalanobis: precomputed_mahalanobis_M&A_bl_9q.pkl
# Precomputing Mahalanobis: 100%|██████████| 419/419 [02:26<00:00,  2.86it/s]
# ✅ Saved: precomputed_mahalanobis_M&A_bl_9q.pkl
# Prepared and saved treated sample for acq_type=M&A, top_tech=False, baseline_begin_period=9 quarters, threshold=None.
# ⚙️ Preparing treated sample for acq_type=M&A, top_tech=True,
# ⚙️ Computing Mahalanobis: precomputed_mahalanobis_M&A_top_tech_80_9q.pkl
# Precomputing Mahalanobis: 100%|██████████| 242/242 [01:25<00:00,  2.82it/s]
# ✅ Saved: precomputed_mahalanobis_M&A_top_tech_80_9q.pkl
# Prepared and saved treated sample for acq_type=M&A, top_tech=True, baseline_begin_period=9 quarters, threshold=80.
# ⚙️ Computing Mahalanobis: precomputed_mahalanobis_Off deal_bl_9q.pkl
# Precomputing Mahalanobis: 100%|██████████| 294/294 [00:46<00:00,  6.28it/s]
# ✅ Saved: precomputed_mahalanobis_Off deal_bl_9q.pkl
# Prepared and saved treated sample for acq_type=Off deal, top_tech=False, baseline_begin_period=9 quarters, threshold=None.
# ⚙️ Preparing treated sample for acq_type=Off deal, top_tech=True,
# ⚙️ Computing Mahalanobis: precomputed_mahalanobis_Off deal_top_tech_80_9q.pkl
# Precomputing Mahalanobis: 100%|██████████| 197/197 [00:37<00:00,  5.24it/s]
# ✅ Saved: precomputed_mahalanobis_Off deal_top_tech_80_9q.pkl
# Prepared and saved treated sample for acq_type=Off deal, top_tech=True, baseline_begin_period=9 quarters, threshold=80.
# Saved treated_counts_dict for baseline_begin_period=13 quarters.
# ⚙️ Computing Mahalanobis: precomputed_mahalanobis_M&A_bl_13q.pkl
# Precomputing Mahalanobis: 100%|██████████| 365/365 [01:57<00:00,  3.10it/s]
# ✅ Saved: precomputed_mahalanobis_M&A_bl_13q.pkl
# Prepared and saved treated sample for acq_type=M&A, top_tech=False, baseline_begin_period=13 quarters, threshold=None.
# ⚙️ Preparing treated sample for acq_type=M&A, top_tech=True,
# ⚙️ Computing Mahalanobis: precomputed_mahalanobis_M&A_top_tech_80_13q.pkl
# Precomputing Mahalanobis: 100%|██████████| 208/208 [01:12<00:00,  2.85it/s]
# ✅ Saved: precomputed_mahalanobis_M&A_top_tech_80_13q.pkl
# Prepared and saved treated sample for acq_type=M&A, top_tech=True, baseline_begin_period=13 quarters, threshold=80.
# ⚙️ Computing Mahalanobis: precomputed_mahalanobis_Off deal_bl_13q.pkl
# Precomputing Mahalanobis: 100%|██████████| 284/284 [00:48<00:00,  5.81it/s]
# ✅ Saved: precomputed_mahalanobis_Off deal_bl_13q.pkl
# Prepared and saved treated sample for acq_type=Off deal, top_tech=False, baseline_begin_period=13 quarters, threshold=None.
# ⚙️ Preparing treated sample for acq_type=Off deal, top_tech=True,
# ⚙️ Computing Mahalanobis: precomputed_mahalanobis_Off deal_top_tech_80_13q.pkl
# Precomputing Mahalanobis: 100%|██████████| 163/163 [00:33<00:00,  4.90it/s]
# ✅ Saved: precomputed_mahalanobis_Off deal_top_tech_80_13q.pkl
# Prepared and saved treated sample for acq_type=Off deal, top_tech=True, baseline_begin_period=13 quarters, threshold=80.
# Saved treated_counts_dict for baseline_begin_period=17 quarters.
# ⚙️ Computing Mahalanobis: precomputed_mahalanobis_M&A_bl_17q.pkl
# Precomputing Mahalanobis: 100%|██████████| 326/326 [01:41<00:00,  3.22it/s]
# ✅ Saved: precomputed_mahalanobis_M&A_bl_17q.pkl
# Prepared and saved treated sample for acq_type=M&A, top_tech=False, baseline_begin_period=17 quarters, threshold=None.
# ⚙️ Preparing treated sample for acq_type=M&A, top_tech=True,
# ⚙️ Computing Mahalanobis: precomputed_mahalanobis_M&A_top_tech_80_17q.pkl
# Precomputing Mahalanobis: 100%|██████████| 177/177 [01:00<00:00,  2.91it/s]
# ✅ Saved: precomputed_mahalanobis_M&A_top_tech_80_17q.pkl
# Prepared and saved treated sample for acq_type=M&A, top_tech=True, baseline_begin_period=17 quarters, threshold=80.
# ⚙️ Computing Mahalanobis: precomputed_mahalanobis_Off deal_bl_17q.pkl
# Precomputing Mahalanobis: 100%|██████████| 234/234 [00:44<00:00,  5.31it/s]
# ✅ Saved: precomputed_mahalanobis_Off deal_bl_17q.pkl
# Prepared and saved treated sample for acq_type=Off deal, top_tech=False, baseline_begin_period=17 quarters, threshold=None.
# ⚙️ Preparing treated sample for acq_type=Off deal, top_tech=True,
# ⚙️ Computing Mahalanobis: precomputed_mahalanobis_Off deal_top_tech_80_17q.pkl
# Precomputing Mahalanobis: 100%|██████████| 166/166 [00:33<00:00,  4.91it/s]
# ✅ Saved: precomputed_mahalanobis_Off deal_top_tech_80_17q.pkl
# Prepared and saved treated sample for acq_type=Off deal, top_tech=True, baseline_begin_period=17 quarters, threshold=80.

# %% [markdown]
# # Run parallelized routine

# %%
import api.matching_optimal_cit_no_exact as matching
import importlib
importlib.reload(matching)

# Run
matching.grid_runner_parallel_K(Ks = [10], max_workers = 2)
# Out:
# 🔁 Launching 12 grid runs in parallel with 2 workers...
#
# [K=10 | M&A, top_tech=True, threshold=80, caliper=0.05, baseline=9q][K=10 | M&A, top_tech=False, threshold=None, caliper=0.05, baseline=9q]
# Grid Search over Lambda: 100%|██████████| 11/11 [05:51<00:00, 31.96s/it]
# Results of grid search:
#     lambda   mse_diff  total_num_patents  num_dropped
# 0      0.0  10.809250               2510            0
# 1      0.1   7.399924               2510            8
# 2      0.2   5.381976               2510           80
# 3      0.3   4.409514               2510          201
# 4      0.4   3.922514               2510          309
# 5      0.5   3.708666               2510          360
# 6      0.6   3.507459               2510          375
# 7      0.7   3.659113               2510          319
# 8      0.8   4.096120               2510          170
# 9      0.9   5.056880               2510           11
# 10     1.0   5.732817               2510            0
# Grid Search over Lambda:  36%|███▋      | 4/11 [05:25<09:31, 81.66s/it]
# [K=10 | Off deal, top_tech=False, threshold=None, caliper=0.05, baseline=9q]
# ✅ Done: K=10, M&A, top_tech=True, threshold=80, caliper=0.05, baseline=9q
# Grid Search over Lambda: 100%|██████████| 11/11 [14:09<00:00, 77.27s/it]
# Results of grid search:
#     lambda  mse_diff  total_num_patents  num_dropped
# 0      0.0  4.851665               8372            0
# 1      0.1  2.959981               8372            8
# 2      0.2  2.008718               8372           88
# 3      0.3  1.554058               8372          212
# 4      0.4  1.321272               8372          327
# 5      0.5  1.205882               8372          386
# 6      0.6  1.129440               8372          395
# 7      0.7  1.174547               8372          334
# 8      0.8  1.354160               8372          172
# 9      0.9  1.749361               8372           11
# 10     1.0  1.970507               8372            0
# Grid Search over Lambda:  64%|██████▎   | 7/11 [06:32<03:30, 52.70s/it]
# [K=10 | Off deal, top_tech=True, threshold=80, caliper=0.05, baseline=9q]
# ✅ Done: K=10, M&A, top_tech=False, threshold=None, caliper=0.05, baseline=9q
# Grid Search over Lambda: 100%|██████████| 11/11 [09:30<00:00, 51.85s/it]
# Results of grid search:
#     lambda  mse_diff  total_num_patents  num_dropped
# 0      0.0
� Done: K=10, Off deal, top_tech=True, threshold=80, caliper=0.05, baseline=13q
# [K=10 | M&A, top_tech=True, threshold=80, caliper=0.05, baseline=17q]
# ✅ Done: K=10, Off deal, top_tech=False, threshold=None, caliper=0.05, baseline=13q
# Grid Search over Lambda: 100%|██████████| 11/11 [03:57<00:00, 21.60s/it]
# Results of grid search:
#     lambda   mse_diff  total_num_patents  num_dropped
# 0      0.0  11.651670               2081            0
# 1      0.1   8.560717               2081            4
# 2      0.2   6.451912               2081           55
# 3      0.3   4.788297               2081          170
# 4      0.4   4.132713               2081          280
# 5      0.5   3.862543               2081          372
# 6      0.6   3.627801               2081          424
# 7      0.7   3.788936               2081          385
# 8      0.8   4.473701               2081          229
# 9      0.9   5.161990               2081           13
# 10     1.0   6.046931               2081            0
# Grid Search over Lambda:  45%|████▌     | 5/11 [04:39<05:33, 55.59s/it]
# [K=10 | Off deal, top_tech=False, threshold=None, caliper=0.05, baseline=17q]
# ✅ Done: K=10, M&A, top_tech=True, threshold=80, caliper=0.05, baseline=17q
# Grid Search over Lambda: 100%|██████████| 11/11 [09:37<00:00, 52.48s/it]
# Results of grid search:
#     lambda  mse_diff  total_num_patents  num_dropped
# 0      0.0  5.369767               6905            0
# 1      0.1  3.501498               6905            5
# 2      0.2  2.444116               6905           66
# 3      0.3  1.725273               6905          203
# 4      0.4  1.402651               6905          330
# 5      0.5  1.215028               6905          445
# 6      0.6  1.094844               6905          501
# 7      0.7  1.117105               6905          448
# 8      0.8  1.371371               6905          263
# 9      0.9  1.783760               6905           15
# 10     1.0  2.148183               6905            0
# Grid Search over Lambda:  73%|███████▎  | 8/11 [03:56<01:24, 28.00s/it]
# [K=10 | Off deal, top_tech=True, threshold=80, caliper=0.05, baseline=17q]
# ✅ Done: K=10, M&A, top_tech=False, threshold=None, caliper=0.05, baseline=17q
# Grid Search over Lambda: 100%|██████████| 11/11 [05:00<00:00, 27.34s/it]
# Results of grid search:
#     lambda  mse_diff  total_num_patents  num_dropped
# 0      0.0  5.185349               3424            0
# 1      0.1  3.925477               3424            0
# 2      0.2  3.203272               3424           15
# 3      0.3  2.623875               3424           52
# 4      0.4  2.270896               3424          104
# 5      0.5  2.009871               3424          152
# 6      0.6  1.906732               3424          174
# 7      0.7  1.902777               3424          153
# 8      0.8  2.264741               3424           95
# 9      0.9  2.682080               3424            8
# 10     1.0  2.734162               3424            0
# ✅ Done: K=10, Off deal, top_tech=False, threshold=None, caliper=0.05, baseline=17q
# Grid Search over Lambda: 100%|██████████| 11/11 [02:34<00:00, 14.01s/it]
# Results of grid search:
#     lambda  mse_diff  total_num_patents  num_dropped
# 0      0.0  8.172841               1560            0
# 1      0.1  6.904387               1560            0
# 2      0.2  5.982282               1560           12
# 3      0.3  5.217673               1560           49
# 4      0.4  4.694563               1560          102
# 5      0.5  4.366246               1560          147
# 6      0.6  4.305369               1560          169
# 7      0.7  4.383532               1560          150
# 8      0.8  5.192847               1560           93
# 9      0.9  5.683611               1560            8
# 10     1.0  5.718909               1560            0
# ✅ Done: K=10, Off deal, top_tech=True, threshold=80, caliper=0.05, baseline=17q
#
# 🎉 All grid points completed.
# ['✅ Done: K=10, M&A, top_tech=True, threshold=80, caliper=0.05, baseline=9q',
#  '✅ Done: K=10, M&A, top_tech=False, threshold=None, caliper=0.05, baseline=9q',
#  '✅ Done: K=10, Off deal, top_tech=False, threshold=None, caliper=0.05, baseline=9q',
#  '✅ Done: K=10, Off deal, top_tech=True, threshold=80, caliper=0.05, baseline=9q',
#  '✅ Done: K=10, M&A, top_tech=True, threshold=80, caliper=0.05, baseline=13q',
#  '✅ Done: K=10, M&A, top_tech=False, threshold=None, caliper=0.05, baseline=13q',
#  '✅ Done: K=10, Off deal, top_tech=True, threshold=80, caliper=0.05, baseline=13q',
#  '✅ Done: K=10, Off deal, top_tech=False, threshold=None, caliper=0.05, baseline=13q',
#  '✅ Done: K=10, M&A, top_tech=True, threshold=80, caliper=0.05, baseline=17q',
#  '✅ Done: K=10, M&A, top_tech=False, threshold=None, caliper=0.05, baseline=17q',
#  '✅ Done: K=10, Off deal, top_tech=False, threshold=None, caliper=0.05, baseline=17q',
#  '✅ Done: K=10, Off deal, top_tech=True, threshold=80, caliper=0.05, baseline=17q']
