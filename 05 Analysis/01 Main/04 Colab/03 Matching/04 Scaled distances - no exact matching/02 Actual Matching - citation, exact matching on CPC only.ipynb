# %% [markdown]
# # Drive and utilities

# %%
#@title Mount Drive to get BERT model
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
#@title Utils
# !pip install dill
# !pip install pandas
# !pip install numpy
!
import dill as pickle
# Out:
# Requirement already satisfied: dill in /usr/local/lib/python3.12/dist-packages (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (2.0.2)

# %%
#@title Clone the repo and add API key
# !git clone https://github.com/amusali/bert_for_patents.git
import os
# Api key setting
os.environ['patentsview_api_key'] = 'Uch9R1RR.BxaQcxV8HK4nBMgTTjX1F9CQW8PF4nXw'  # Replace with your actual key
# Out:
# Cloning into 'bert_for_patents'...
# remote: Enumerating objects: 1781, done.
# remote: Counting objects: 100% (39/39), done.
# remote: Compressing objects: 100% (24/24), done.
# remote: Total 1781 (delta 20), reused 28 (delta 15), pack-reused 1742 (from 2)
# Receiving objects: 100% (1781/1781), 197.70 MiB | 15.99 MiB/s, done.
# Resolving deltas: 100% (979/979), done.

# %%
#@title Run setup file to get environment
#!python "/content/bert_for_patents/05 Analysis/01 Main/setup_colab.py"

import sys
sys.path.append('/content/bert_for_patents/05 Analysis/01 Main')
os.chdir("/content/bert_for_patents/05 Analysis/01 Main")

# %%
#@title Pull latest changes from repo
# %cd "/content/bert_for_patents"
# !git pull origin master
#@title Add paths to the system and change directory
import sys
sys.path.append('/content/bert_for_patents/05 Analysis/01 Main')
os.chdir("/content/bert_for_patents/05 Analysis/01 Main")
# Out:
# /content/bert_for_patents
# remote: Enumerating objects: 11, done.
# remote: Counting objects: 100% (11/11), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 6 (delta 4), reused 6 (delta 4), pack-reused 0 (from 0)
# Unpacking objects: 100% (6/6), 524 bytes | 262.00 KiB/s, done.
# From https://github.com/amusali/bert_for_patents
#  * branch            master     -> FETCH_HEAD
#    0c99c54..7f12234  master     -> origin/master
# Updating 0c99c54..7f12234
# Fast-forward
#  05 Analysis/01 Main/api/matching_cit_no_exact.py | 6 +++---
#  1 file changed, 3 insertions(+), 3 deletions(-)

# %% [markdown]
# # Prepare

# %%
import api.matching_cit_no_exact as matching
import importlib
importlib.reload(matching)

# Prepare
matching.prepare()
# Out:
# Loaded data: 145878465 citations, 19649 treated patents, 5941114 control patents, 5805396 clean ids.
# Preprocessed data: 89274607 citations, 19649 treated patents, 5805396 control patents.
# Saved treated_counts_dict for baseline_begin_period=4 quarters.
# ⚙️ Computing Mahalanobis: precomputed_mahalanobis_M&A_bl_4q.pkl
# Precomputing Mahalanobis: 100%|██████████| 504/504 [03:17<00:00,  2.56it/s]
# ✅ Saved: precomputed_mahalanobis_M&A_bl_4q.pkl
# Prepared and saved treated sample for acq_type=M&A, top_tech=False, baseline_begin_period=4 quarters, threshold=None.
# ⚙️ Preparing treated sample for acq_type=M&A, top_tech=True,
# ⚙️ Computing Mahalanobis: precomputed_mahalanobis_M&A_top_tech_80_4q.pkl
# Precomputing Mahalanobis: 100%|██████████| 289/289 [02:01<00:00,  2.38it/s]
# ✅ Saved: precomputed_mahalanobis_M&A_top_tech_80_4q.pkl
# Prepared and saved treated sample for acq_type=M&A, top_tech=True, baseline_begin_period=4 quarters, threshold=80.
# ⚙️ Computing Mahalanobis: precomputed_mahalanobis_Off deal_bl_4q.pkl
# Precomputing Mahalanobis: 100%|██████████| 305/305 [00:53<00:00,  5.70it/s]
# ✅ Saved: precomputed_mahalanobis_Off deal_bl_4q.pkl
# Prepared and saved treated sample for acq_type=Off deal, top_tech=False, baseline_begin_period=4 quarters, threshold=None.
# ⚙️ Preparing treated sample for acq_type=Off deal, top_tech=True,
# ⚙️ Computing Mahalanobis: precomputed_mahalanobis_Off deal_top_tech_80_4q.pkl
# Precomputing Mahalanobis: 100%|██████████| 206/206 [00:41<00:00,  5.00it/s]
# ✅ Saved: precomputed_mahalanobis_Off deal_top_tech_80_4q.pkl
# Prepared and saved treated sample for acq_type=Off deal, top_tech=True, baseline_begin_period=4 quarters, threshold=80.
# Saved treated_counts_dict for baseline_begin_period=6 quarters.
# ⚙️ Computing Mahalanobis: precomputed_mahalanobis_M&A_bl_6q.pkl
# Precomputing Mahalanobis: 100%|██████████| 466/466 [03:12<00:00,  2.42it/s]
# ✅ Saved: precomputed_mahalanobis_M&A_bl_6q.pkl
# Prepared and saved treated sample for acq_type=M&A, top_tech=False, baseline_begin_period=6 quarters, threshold=None.
# ⚙️ Preparing treated sample for acq_type=M&A, top_tech=True,
# ⚙️ Computing Mahalanobis: precomputed_mahalanobis_M&A_top_tech_80_6q.pkl
# Precomputing Mahalanobis: 100%|██████████| 234/234 [01:38<00:00,  2.37it/s]
# ✅ Saved: precomputed_mahalanobis_M&A_top_tech_80_6q.pkl
# Prepared and saved treated sample for acq_type=M&A, top_tech=True, baseline_begin_period=6 quarters, threshold=80.
# ⚙️ Computing Mahalanobis: precomputed_mahalanobis_Off deal_bl_6q.pkl
# Precomputing Mahalanobis: 100%|██████████| 301/301 [00:56<00:00,  5.29it/s]
# ✅ Saved: precomputed_mahalanobis_Off deal_bl_6q.pkl
# Prepared and saved treated sample for acq_type=Off deal, top_tech=False, baseline_begin_period=6 quarters, threshold=None.
# ⚙️ Preparing treated sample for acq_type=Off deal, top_tech=True,
# ⚙️ Computing Mahalanobis: precomputed_mahalanobis_Off deal_top_tech_80_6q.pkl
# Precomputing Mahalanobis: 100%|██████████| 162/162 [00:38<00:00,  4.26it/s]
# ✅ Saved: precomputed_mahalanobis_Off deal_top_tech_80_6q.pkl
# Prepared and saved treated sample for acq_type=Off deal, top_tech=True, baseline_begin_period=6 quarters, threshold=80.
# Saved treated_counts_dict for baseline_begin_period=8 quarters.
# ⚙️ Computing Mahalanobis: precomputed_mahalanobis_M&A_bl_8q.pkl
# Precomputing Mahalanobis: 100%|██████████| 439/439 [03:03<00:00,  2.40it/s]
# ✅ Saved: precomputed_mahalanobis_M&A_bl_8q.pkl
# Prepared and saved treated sample for acq_type=M&A, top_tech=False, baseline_begin_period=8 quarters, threshold=None.
# ⚙️ Preparing treated sample for acq_type=M&A, top_tech=True,
# ⚙️ Computing Mahalanobis: precomputed_mahalanobis_M&A_top_tech_80_8q.pkl
# Precomputing Mahalanobis: 100%|██████████| 228/228 [01:41<00:00,  2.25it/s]
# ✅ Saved: precomputed_mahalanobis_M&A_top_tech_80_8q.pkl
# Prepared and saved treated sample for acq_type=M&A, top_tech=True, baseline_begin_period=8 quarters, threshold=80.
# ⚙️ Computing Mahalanobis: precomputed_mahalanobis_Off deal_bl_8q.pkl
# Precomputing Mahalanobis: 100%|██████████| 296/296 [01:00<00:00,  4.89it/s]
# ✅ Saved: precomputed_mahalanobis_Off deal_bl_8q.pkl
# Prepared and saved treated sample for acq_type=Off deal, top_tech=False, baseline_begin_period=8 quarters, threshold=None.
# ⚙️ Preparing treated sample for acq_type=Off deal, top_tech=True,
# ⚙️ Computing Mahalanobis: precomputed_mahalanobis_Off deal_top_tech_80_8q.pkl
# Precomputing Mahalanobis: 100%|██████████| 175/175 [00:43<00:00,  4.02it/s]
# ✅ Saved: precomputed_mahalanobis_Off deal_top_tech_80_8q.pkl
# Prepared and saved treated sample for acq_type=Off deal, top_tech=True, baseline_begin_period=8 quarters, threshold=80.

# %% [markdown]
# # Run parallelized routine

# %%
import api.matching_cit_no_exact as matching
import importlib
importlib.reload(matching)

# Run
matching.grid_runner_parallel_K(Ks = [10], max_workers = 1)
# Out:
# 🔁 Launching 24 grid runs in parallel with 1 workers...
# Grid Jobs:   0%|          | 0/24 [00:00<?, ?it/s]
# [K=10 | M&A, top_tech=False, threshold=None, caliper=0.05, baseline=4q]
# Grid Search over Lambda: 100%|██████████| 5/5 [07:27<00:00, 89.59s/it]
# Results of grid search:
#    lambda  total_num_patents  num_dropped
# 0    0.00               9499            0
# 1    0.25               9499          169
# 2    0.50               9499          465
# 3    0.75               9499          355
# 4    1.00               9499            0
# Grid Jobs:   4%|▍         | 1/24 [15:08<5:48:15, 908.50s/it]
# [K=10 | M&A, top_tech=False, threshold=None, caliper=0.1, baseline=4q]✅ Done: K=10, M&A, top_tech=False, threshold=None, caliper=0.05, baseline=4q
# Grid Search over Lambda: 100%|██████████| 5/5 [06:02<00:00, 72.57s/it]
# Results of grid search:
#    lambda  total_num_patents  num_dropped
# 0    0.00               9499            0
# 1    0.25               9499           19
# 2    0.50               9499           46
# 3    0.75               9499            5
# 4    1.00               9499            0
# Grid Jobs:   8%|▊         | 2/24 [25:02<4:25:23, 723.78s/it]
# [K=10 | M&A, top_tech=True, threshold=80, caliper=0.05, baseline=4q]✅ Done: K=10, M&A, top_tech=False, threshold=None, caliper=0.1, baseline=4q
# Grid Search over Lambda: 100%|██████████| 5/5 [02:48<00:00, 33.64s/it]
# Results of grid search:
#    lambda  total_num_patents  num_dropped
# 0    0.00               2604            0
# 1    0.25               2604          164
# 2    0.50               2604          442
# 3    0.75               2604          347
# 4    1.00               2604            0
# Grid Jobs:  12%|█▎        | 3/24 [30:34<3:10:39, 544.73s/it]
# [K=10 | M&A, top_tech=True, threshold=80, caliper=0.1, baseline=4q]✅ Done: K=10, M&A, top_tech=True, threshold=80, caliper=0.05, baseline=4q
# Grid Search over Lambda: 100%|██████████| 5/5 [02:05<00:00, 25.15s/it]
# Results of grid search:
#    lambda  total_num_patents  num_dropped
# 0    0.00               2604            0
# 1    0.25               2604           17
# 2    0.50               2604           43
# 3    0.75               2604            5
# 4    1.00               2604            0
# Grid Jobs:  17%|█▋        | 4/24 [35:09<2:26:00, 438.05s/it]
# [K=10 | Off deal, top_tech=False, threshold=None, caliper=0.05, baseline=4q]✅ Done: K=10, M&A, top_tech=True, threshold=80, caliper=0.1, baseline=4q
# Grid Search over Lambda: 100%|██████████| 5/5 [05:00<00:00, 60.11s/it]
# Results of grid search:
#    lambda  total_num_patents  num_dropped
# 0    0.00               6672            0
# 1    0.25               6672           32
# 2    0.50               6672          129
# 3    0.75               6672           86
# 4    1.00               6672            0
# Grid Jobs:  21%|██        | 5/24 [43:59<2:29:14, 471.31s/it]
# [K=10 | Off deal, top_tech=False, threshold=None, caliper=0.1, baseline=4q]✅ Done: K=10, Off deal, top_tech=False, threshold=None, caliper=0.05, baseline=4q
# Grid Search over Lambda: 100%|██████████| 5/5 [03:50<00:00, 46.13s/it]
# Results of grid search:
#    lambda  total_num_patents  num_dropped
# 0    0.00               6672            0
# 1    0.25               6672            1
# 2    0.50               6672            8
# 3    0.75               6672            0
# 4    1.00               6672            0
# Grid Jobs:  25%|██▌       | 6/24 [50:57<2:15:58, 453.24s/it]
# [K=10 | Off deal, top_tech=True, threshold=80, caliper=0.05, baseline=4q]✅ Done: K=10, Off deal, top_tech=False, threshold=None, caliper=0.1, baseline=4q
# Grid Search over Lambda: 100%|██████████| 5/5 [02:06<00:00, 25.35s/it]
# Results of grid search:
#    lambda  total_num_patents  num_dropped
# 0    0.00               2526            0
# 1    0.25               2526           32
# 2    0.50               2526          125
# 3    0.75               2526           85
# 4    1.00               2526            0
# Grid Jobs:  29%|██▉       | 7/24 [55:44<1:52:59, 398.79s/it]
# [K=10 | Off deal, top_tech=True, threshold=80, caliper=0.1, baseline=4q]✅ Done: K=10, Off deal, top_tech=True, threshold=80, caliper=0.05, baseline=4q
# Grid Search over Lambda: 100%|██████████| 5/5 [01:33<00:00, 18.74s/it]
# Results of grid search:
#    lambda  total_num_patents  num_dropped
# 0    0.00               2526            0
# 1    0.25               2526            1
# 2    0.50               2526            8
# 3    0.75               2526            0
# 4    1.00               2526            0
# Grid Jobs:  33%|███▎      | 8/24 [59:46<1:33:02, 348.88s/it]
# [K=10 | M&A, top_tech=False, threshold=None, caliper=0.05, baseline=6q]✅ Done: K=10, Off deal, top_tech=True, threshold=80, caliper=0.1, baseline=4q
# Grid Search over Lambda: 100%|██████████| 5/5 [06:42<00:00, 80.42s/it]
# Results of grid search:
#    lambda  total_num_patents  num_dropped
# 0    0.00               9027            0
# 1    0.25               9027          160
# 2    0.50               9027          462
# 3    0.75               9027          413
# 4    1.00               9027            0
# Grid Jobs:  38%|███▊      | 9/24 [1:10:56<1:52:20, 449.35s/it]
# [K=10 | M&A, top_tech=False, threshold=None, caliper=0.1, baseline=6q]✅ Done: K=10, M&A, top_tech=False, threshold=None, caliper=0.05, baseline=6q
# Grid Search over Lambda: 100%|██████████| 5/5 [05:24<00:00, 64.94s/it]
# Results of grid search:
#    lambda  total_num_patents  num_dropped
# 0    0.00               9027            0
# 1    0.25               9027           18
# 2    0.50               9027           50
# 3    0.75               9027            8
# 4    1.00               9027            0
# Grid Jobs:  42%|████▏     | 10/24 [1:20:06<1:52:07, 480.52s/it]
# [K=10 | M&A, top_tech=True, threshold=80, caliper=0.05, baseline=6q]✅ Done: K=10, M&A, top_tech=False, threshold=None, caliper=0.1, baseline=6q
# Grid Search over Lambda: 100%|██████████| 5/5 [02:04<00:00, 24.97s/it]
# Results of grid search:
#    lambda  total_num_patents  num_dropped
# 0    0.00               1861            0
# 1    0.25               1861          140
# 2    0.50               1861          389
# 3    0.75               1861          354
# 4    1.00               1861            0
# Grid Jobs:  46%|████▌     | 11/24 [1:24:43<1:30:34, 418.06s/it]
# [K=10 | M&A, top_tech=True, threshold=80, caliper=0.1, baseline=6q]✅ Done: K=10, M&A, top_tech=True, threshold=80, caliper=0.05, baseline=6q
# Grid Search over Lambda: 100%|██████████| 5/5 [01:30<00:00, 18.09s/it]
# Results of grid search:
#    lambda  total_num_patents  num_dropped
# 0    0.00               1861            0
# 1    0.25               1861           15
# 2    0.50               1861           43
# 3    0.75               1861            7
# 4    1.00               1861            0
# Grid Jobs:  50%|█████     | 12/24 [1:28:31<1:12:03, 360.26s/it]
# [K=10 | Off deal, top_tech=False, threshold=None, caliper=0.05, baseline=6q]✅ Done: K=10, M&A, top_tech=True, threshold=80, caliper=0.1, baseline=6q
# Grid Search over Lambda: 100%|██████████| 5/5 [04:34<00:00, 54.95s/it]
# Results of grid search:
#    lambda  total_num_patents  num_dropped
# 0    0.00               6333            0
# 1    0.25               6333           34
# 2    0.50               6333          131
# 3    0.75               6333          107
# 4    1.00               6333            0
# Grid Jobs:  54%|█████▍    | 13/24 [1:36:56<1:14:05, 404.14s/it]
# [K=10 | Off deal, top_tech=False, threshold=None, caliper=0.1, baseline=6q]✅ Done: K=10, Off deal, top_tech=False, threshold=None, caliper=0.05, baseline=6q
# Grid Search over Lambda: 100%|██████████| 5/5 [03:27<00:00, 41.45s/it]
# Results of grid search:
#    lambda  total_num_patents  num_dropped
# 0    0.00               6333            0
# 1    0.25               6333            1
# 2    0.50               6333           10
# 3    0.75               6333            0
# 4    1.00               6333            0
# Grid Jobs:  58%|█████▊    | 14/24 [1:43:34<1:07:01, 402.18s/it]
# [K=10 | Off deal, top_tech=True, threshold=80, caliper=0.05, baseline=6q]✅ Done: K=10, Off deal, top_tech=False, threshold=None, caliper=0.1, baseline=6q
# Grid Search over Lambda: 100%|██████████| 5/5 [01:27<00:00, 17.44s/it]
# Results of grid search:
#    lambda  total_num_patents  num_dropped
# 0    0.00               1666            0
# 1    0.25               1666           31
# 2    0.50               1666          117
# 3    0.75               1666          104
# 4    1.00               1666            0
# Grid Jobs:  62%|██████▎   | 15/24 [1:47:29<52:46, 351.89s/it]
# [K=10 | Off deal, top_tech=True, threshold=80, caliper=0.1, baseline=6q]✅ Done: K=10, Off deal, top_tech=True, threshold=80, caliper=0.05, baseline=6q
# Grid Search over Lambda: 100%|██████████| 5/5 [01:00<00:00, 12.19s/it]
# Results of grid search:
#    lambda  total_num_patents  num_dropped
# 0    0.00               1666            0
# 1    0.25               1666            1
# 2    0.50               1666           10
# 3    0.75               1666            0
# 4    1.00               1666            0
# Grid Jobs:  67%|██████▋   | 16/24 [1:50:49<40:50, 306.28s/it]
# [K=10 | M&A, top_tech=False, threshold=None, caliper=0.05, baseline=8q]✅ Done: K=10, Off deal, top_tech=True, threshold=80, caliper=0.1, baseline=6q
# Grid Search over Lambda: 100%|██████████| 5/5 [06:04<00:00, 72.84s/it]
# Results of grid search:
#    lambda  total_num_patents  num_dropped
# 0    0.00               8595            0
# 1    0.25               8595          151
# 2    0.50               8595          494
# 3    0.75               8595          456
# 4    1.00               8595            0
# Grid Jobs:  71%|███████   | 17/24 [2:01:18<47:01, 403.14s/it]
# [K=10 | M&A, top_tech=False, threshold=None, caliper=0.1, baseline=8q]✅ Done: K=10, M&A, top_tech=False, threshold=None, caliper=0.05, baseline=8q
# Grid Search over Lambda: 100%|██████████| 5/5 [04:44<00:00, 56.81s/it]
# Results of grid search:
#    lambda  total_num_patents  num_dropped
# 0    0.00               8595            0
# 1    0.25               8595           19
# 2    0.50               8595           59
# 3    0.75               8595           11
# 4    1.00               8595            0
# Grid Jobs:  75%|███████▌  | 18/24 [2:09:49<43:34, 435.72s/it]
# [K=10 | M&A, top_tech=True, threshold=80, caliper=0.05, baseline=8q]✅ Done: K=10, M&A, top_tech=False, threshold=None, caliper=0.1, baseline=8q
# Grid Search over Lambda: 100%|██████████| 5/5 [02:00<00:00, 24.06s/it]
# Results of grid search:
#    lambda  total_num_patents  num_dropped
# 0    0.00               1940            0
# 1    0.25               1940          133
# 2    0.50               1940          393
# 3    0.75               1940          328
# 4    1.00               1940            0
# Grid Jobs:  79%|███████▉  | 19/24 [2:14:26<32:19, 387.97s/it]
# [K=10 | M&A, top_tech=True, threshold=80, caliper=0.1, baseline=8q]✅ Done: K=10, M&A, top_tech=True, threshold=80, caliper=0.05, baseline=8q
# Grid Search over Lambda: 100%|██████████| 5/5 [01:25<00:00, 17.05s/it]
# Results of grid search:
#    lambda  total_num_patents  num_dropped
# 0    0.00               1940            0
# 1    0.25               1940           17
# 2    0.50               1940           49
# 3    0.75               1940            9
# 4    1.00               1940            0
# Grid Jobs:  83%|████████▎ | 20/24 [2:18:14<22:39, 339.94s/it]
# [K=10 | Off deal, top_tech=False, threshold=None, caliper=0.05, baseline=8q]✅ Done: K=10, M&A, top_tech=True, threshold=80, caliper=0.1, baseline=8q
# Grid Search over Lambda: 100%|██████████| 5/5 [04:10<00:00, 50.09s/it]
# Results of grid search:
#    lambda  total_num_patents  num_dropped
# 0    0.00               5989            0
# 1    0.25               5989           34
# 2    0.50               5989          132
# 3    0.75               5989          125
# 4    1.00               5989            0
# Grid Jobs:  88%|████████▊ | 21/24 [2:26:05<18:58, 379.39s/it]
# [K=10 | Off deal, top_tech=False, threshold=None, caliper=0.1, baseline=8q]✅ Done: K=10, Off deal, top_tech=False, threshold=None, caliper=0.05, baseline=8q
# Grid Search over Lambda: 100%|██████████| 5/5 [03:04<00:00, 36.83s/it]
# Results of grid search:
#    lambda  total_num_patents  num_dropped
# 0    0.00               5989            0
# 1    0.25               5989            1
# 2    0.50               5989            8
# 3    0.75               5989            2
# 4    1.00               5989            0
# Grid Jobs:  92%|█████████▏| 22/24 [2:32:23<12:37, 378.92s/it]
# [K=10 | Off deal, top_tech=True, threshold=80, caliper=0.05, baseline=8q]✅ Done: K=10, Off deal, top_tech=False, threshold=None, caliper=0.1, baseline=8q
# Grid Search over Lambda: 100%|██████████| 5/5 [01:35<00:00, 19.18s/it]
# Results of grid search:
#    lambda  total_num_patents  num_dropped
# 0    0.00               1989            0
# 1    0.25               1989           30
# 2    0.50               1989          122
# 3    0.75               1989          120
# 4    1.00               1989            0
# Grid Jobs:  96%|█████████▌| 23/24 [2:36:38<05:41, 341.75s/it]
# [K=10 | Off deal, top_tech=True, threshold=80, caliper=0.1, baseline=8q]✅ Done: K=10, Off deal, top_tech=True, threshold=80, caliper=0.05, baseline=8q
# Grid Search over Lambda: 100%|██████████| 5/5 [01:06<00:00, 13.37s/it]
# Results of grid search:
#    lambda  total_num_patents  num_dropped
# 0    0.00               1989            0
# 1    0.25               1989            1
# 2    0.50               1989            8
# 3    0.75               1989            1
# 4    1.00               1989            0
# Grid Jobs: 100%|██████████| 24/24 [2:40:07<00:00, 400.32s/it]
# ✅ Done: K=10, Off deal, top_tech=True, threshold=80, caliper=0.1, baseline=8q
# 🎉 All grid points completed.
# ['✅ Done: K=10, M&A, top_tech=False, threshold=None, caliper=0.05, baseline=4q',
#  '✅ Done: K=10, M&A, top_tech=False, threshold=None, caliper=0.1, baseline=4q',
#  '✅ Done: K=10, M&A, top_tech=True, threshold=80, caliper=0.05, baseline=4q',
#  '✅ Done: K=10, M&A, top_tech=True, threshold=80, caliper=0.1, baseline=4q',
#  '✅ Done: K=10, Off deal, top_tech=False, threshold=None, caliper=0.05, baseline=4q',
#  '✅ Done: K=10, Off deal, top_tech=False, threshold=None, caliper=0.1, baseline=4q',
#  '✅ Done: K=10, Off deal, top_tech=True, threshold=80, caliper=0.05, baseline=4q',
#  '✅ Done: K=10, Off deal, top_tech=True, threshold=80, caliper=0.1, baseline=4q',
#  '✅ Done: K=10, M&A, top_tech=False, threshold=None, caliper=0.05, baseline=6q',
#  '✅ Done: K=10, M&A, top_tech=False, threshold=None, caliper=0.1, baseline=6q',
#  '✅ Done: K=10, M&A, top_tech=True, threshold=80, caliper=0.05, baseline=6q',
#  '✅ Done: K=10, M&A, top_tech=True, threshold=80, caliper=0.1, baseline=6q',
#  '✅ Done: K=10, Off deal, top_tech=False, threshold=None, caliper=0.05, baseline=6q',
#  '✅ Done: K=10, Off deal, top_tech=False, threshold=None, caliper=0.1, baseline=6q',
#  '✅ Done: K=10, Off deal, top_tech=True, threshold=80, caliper=0.05, baseline=6q',
#  '✅ Done: K=10, Off deal, top_tech=True, threshold=80, caliper=0.1, baseline=6q',
#  '✅ Done: K=10, M&A, top_tech=False, threshold=None, caliper=0.05, baseline=8q',
#  '✅ Done: K=10, M&A, top_tech=False, threshold=None, caliper=0.1, baseline=8q',
#  '✅ Done: K=10, M&A, top_tech=True, threshold=80, caliper=0.05, baseline=8q',
#  '✅ Done: K=10, M&A, top_tech=True, threshold=80, caliper=0.1, baseline=8q',
#  '✅ Done: K=10, Off deal, top_tech=False, threshold=None, caliper=0.05, baseline=8q',
#  '✅ Done: K=10, Off deal, top_tech=False, threshold=None, caliper=0.1, baseline=8q',
#  '✅ Done: K=10, Off deal, top_tech=True, threshold=80, caliper=0.05, baseline=8q',
#  '✅ Done: K=10, Off deal, top_tech=True, threshold=80, caliper=0.1, baseline=8q']
