# %% [markdown]
# # Drive and utilities

# %%
#@title Mount Drive to get BERT model
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
#@title Utils
# !pip install dill
# !pip install pandas
# !pip install numpy
!
import dill as pickle
# Out:
# Requirement already satisfied: dill in /usr/local/lib/python3.11/dist-packages (0.3.7)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (2.0.2)

# %%
#@title Clone the repo and add API key
# !git clone https://github.com/amusali/bert_for_patents.git
import os
# Api key setting
os.environ['patentsview_api_key'] = 'Uch9R1RR.BxaQcxV8HK4nBMgTTjX1F9CQW8PF4nXw'  # Replace with your actual key
# Out:
# Cloning into 'bert_for_patents'...
# remote: Enumerating objects: 1359, done.
# remote: Counting objects: 100% (31/31), done.
# remote: Compressing objects: 100% (19/19), done.
# remote: Total 1359 (delta 16), reused 23 (delta 12), pack-reused 1328 (from 1)
# Receiving objects: 100% (1359/1359), 180.75 MiB | 13.61 MiB/s, done.
# Resolving deltas: 100% (759/759), done.

# %%
#@title Run setup file to get environment
#!python "/content/bert_for_patents/05 Analysis/01 Main/setup_colab.py"

import sys
sys.path.append('/content/bert_for_patents/05 Analysis/01 Main')
os.chdir("/content/bert_for_patents/05 Analysis/01 Main")

# %%
#@title Pull latest changes from repo
# %cd "/content/bert_for_patents"
# !git pull origin master
#@title Add paths to the system and change directory
import sys
sys.path.append('/content/bert_for_patents/05 Analysis/01 Main')
os.chdir("/content/bert_for_patents/05 Analysis/01 Main")
# Out:
# /content/bert_for_patents
# From https://github.com/amusali/bert_for_patents
#  * branch            master     -> FETCH_HEAD
# Already up to date.

# %% [markdown]
# # Prepare

# %%
import api.matching_cit as matching
import importlib
importlib.reload(matching)

# Prepare
matching.prepare()
# Out:
# Loaded data: 145878465 citations, 19760 treated patents, 2876736 control patents, 2758562 clean ids.
# Preprocessed data: 44962852 citations, 19760 treated patents, 2758562 control patents.
# Precompute Cosine Distances: 100%|██████████| 1632/1632 [05:45<00:00,  4.73it/s]
# Saved treated_counts_dict for baseline_begin_period=4 quarters.
# ⚙️ Computing Mahalanobis: precomputed_mahalanobis_M&A_bl_4q.pkl
# Precomputing Mahalanobis: 100%|██████████| 1895/1895 [00:42<00:00, 44.90it/s]
# ✅ Saved: precomputed_mahalanobis_M&A_bl_4q.pkl
# Prepared and saved treated sample for acq_type=M&A, top_tech=False, baseline_begin_period=4 quarters, threshold=None.
# ⚙️ Computing Mahalanobis: precomputed_mahalanobis_M&A_top_tech_80_4q.pkl
# Precomputing Mahalanobis: 100%|██████████| 909/909 [00:20<00:00, 44.89it/s]
# ✅ Saved: precomputed_mahalanobis_M&A_top_tech_80_4q.pkl
# ⚙️ Computing Mahalanobis: precomputed_mahalanobis_M&A_top_tech_90_4q.pkl
# Precomputing Mahalanobis: 100%|██████████| 533/533 [00:11<00:00, 46.14it/s]
# ✅ Saved: precomputed_mahalanobis_M&A_top_tech_90_4q.pkl
# Prepared and saved treated sample for acq_type=M&A, top_tech=True, baseline_begin_period=4 quarters, threshold=90.
# ⚙️ Computing Mahalanobis: precomputed_mahalanobis_Off deal_bl_4q.pkl
# Precomputing Mahalanobis: 100%|██████████| 1056/1056 [00:14<00:00, 70.86it/s]
# ✅ Saved: precomputed_mahalanobis_Off deal_bl_4q.pkl
# Prepared and saved treated sample for acq_type=Off deal, top_tech=False, baseline_begin_period=4 quarters, threshold=None.
# ⚙️ Computing Mahalanobis: precomputed_mahalanobis_Off deal_top_tech_80_4q.pkl
# Precomputing Mahalanobis: 100%|██████████| 639/639 [00:09<00:00, 64.34it/s]
# ✅ Saved: precomputed_mahalanobis_Off deal_top_tech_80_4q.pkl
# ⚙️ Computing Mahalanobis: precomputed_mahalanobis_Off deal_top_tech_90_4q.pkl
# Precomputing Mahalanobis: 100%|██████████| 340/340 [00:06<00:00, 54.36it/s]
# ✅ Saved: precomputed_mahalanobis_Off deal_top_tech_90_4q.pkl
# Prepared and saved treated sample for acq_type=Off deal, top_tech=True, baseline_begin_period=4 quarters, threshold=90.
# Saved treated_counts_dict for baseline_begin_period=6 quarters.
# ⚙️ Computing Mahalanobis: precomputed_mahalanobis_M&A_bl_6q.pkl
# Precomputing Mahalanobis: 100%|██████████| 1754/1754 [00:39<00:00, 44.62it/s]
# ✅ Saved: precomputed_mahalanobis_M&A_bl_6q.pkl
# Prepared and saved treated sample for acq_type=M&A, top_tech=False, baseline_begin_period=6 quarters, threshold=None.
# ⚙️ Computing Mahalanobis: precomputed_mahalanobis_M&A_top_tech_80_6q.pkl
# Precomputing Mahalanobis: 100%|██████████| 702/702 [00:16<00:00, 42.56it/s]
# ✅ Saved: precomputed_mahalanobis_M&A_top_tech_80_6q.pkl
# ⚙️ Computing Mahalanobis: precomputed_mahalanobis_M&A_top_tech_90_6q.pkl
# Precomputing Mahalanobis: 100%|██████████| 495/495 [00:11<00:00, 42.54it/s]
# ✅ Saved: precomputed_mahalanobis_M&A_top_tech_90_6q.pkl
# Prepared and saved treated sample for acq_type=M&A, top_tech=True, baseline_begin_period=6 quarters, threshold=90.
# ⚙️ Computing Mahalanobis: precomputed_mahalanobis_Off deal_bl_6q.pkl
# Precomputing Mahalanobis: 100%|██████████| 1026/1026 [00:16<00:00, 63.01it/s]
# ✅ Saved: precomputed_mahalanobis_Off deal_bl_6q.pkl
# Prepared and saved treated sample for acq_type=Off deal, top_tech=False, baseline_begin_period=6 quarters, threshold=None.
# ⚙️ Computing Mahalanobis: precomputed_mahalanobis_Off deal_top_tech_80_6q.pkl
# Precomputing Mahalanobis: 100%|██████████| 487/487 [00:09<00:00, 52.74it/s]
# ✅ Saved: precomputed_mahalanobis_Off deal_top_tech_80_6q.pkl
# ⚙️ Computing Mahalanobis: precomputed_mahalanobis_Off deal_top_tech_90_6q.pkl
# Precomputing Mahalanobis: 100%|██████████| 326/326 [00:06<00:00, 47.63it/s]
# ✅ Saved: precomputed_mahalanobis_Off deal_top_tech_90_6q.pkl
# Prepared and saved treated sample for acq_type=Off deal, top_tech=True, baseline_begin_period=6 quarters, threshold=90.
# Saved treated_counts_dict for baseline_begin_period=8 quarters.
# ⚙️ Computing Mahalanobis: precomputed_mahalanobis_M&A_bl_8q.pkl
# Precomputing Mahalanobis: 100%|██████████| 1663/1663 [00:39<00:00, 42.10it/s]
# ✅ Saved: precomputed_mahalanobis_M&A_bl_8q.pkl
# Prepared and saved treated sample for acq_type=M&A, top_tech=False, baseline_begin_period=8 quarters, threshold=None.
# ⚙️ Computing Mahalanobis: precomputed_mahalanobis_M&A_top_tech_80_8q.pkl
# Precomputing Mahalanobis: 100%|██████████| 714/714 [00:17<00:00, 39.92it/s]
# ✅ Saved: precomputed_mahalanobis_M&A_top_tech_80_8q.pkl
# ⚙️ Computing Mahalanobis: precomputed_mahalanobis_M&A_top_tech_90_8q.pkl
# Precomputing Mahalanobis: 100%|██████████| 452/452 [00:11<00:00, 40.90it/s]
# ✅ Saved: precomputed_mahalanobis_M&A_top_tech_90_8q.pkl
# Prepared and saved treated sample for acq_type=M&A, top_tech=True, baseline_begin_period=8 quarters, threshold=90.
# ⚙️ Computing Mahalanobis: precomputed_mahalanobis_Off deal_bl_8q.pkl
# Precomputing Mahalanobis: 100%|██████████| 990/990 [00:16<00:00, 59.91it/s]
# ✅ Saved: precomputed_mahalanobis_Off deal_bl_8q.pkl
# Prepared and saved treated sample for acq_type=Off deal, top_tech=False, baseline_begin_period=8 quarters, threshold=None.
# ⚙️ Computing Mahalanobis: precomputed_mahalanobis_Off deal_top_tech_80_8q.pkl
# Precomputing Mahalanobis: 100%|██████████| 531/531 [00:10<00:00, 49.31it/s]
# ✅ Saved: precomputed_mahalanobis_Off deal_top_tech_80_8q.pkl
# ⚙️ Computing Mahalanobis: precomputed_mahalanobis_Off deal_top_tech_90_8q.pkl
# Precomputing Mahalanobis: 100%|██████████| 324/324 [00:07<00:00, 44.43it/s]
# ✅ Saved: precomputed_mahalanobis_Off deal_top_tech_90_8q.pkl
# Prepared and saved treated sample for acq_type=Off deal, top_tech=True, baseline_begin_period=8 quarters, threshold=90.
# Saved treated_counts_dict for baseline_begin_period=10 quarters.
# ⚙️ Computing Mahalanobis: precomputed_mahalanobis_M&A_bl_10q.pkl
# Precomputing Mahalanobis: 100%|██████████| 1539/1539 [00:37<00:00, 40.77it/s]
# ✅ Saved: precomputed_mahalanobis_M&A_bl_10q.pkl
# Prepared and saved treated sample for acq_type=M&A, top_tech=False, baseline_begin_period=10 quarters, threshold=None.
# ⚙️ Computing Mahalanobis: precomputed_mahalanobis_M&A_top_tech_80_10q.pkl
# Precomputing Mahalanobis: 100%|██████████| 684/684 [00:18<00:00, 37.63it/s]
# ✅ Saved: precomputed_mahalanobis_M&A_top_tech_80_10q.pkl
# ⚙️ Computing Mahalanobis: precomputed_mahalanobis_M&A_top_tech_90_10q.pkl
# Precomputing Mahalanobis: 100%|██████████| 441/441 [00:11<00:00, 37.68it/s]
# ✅ Saved: precomputed_mahalanobis_M&A_top_tech_90_10q.pkl
# Prepared and saved treated sample for acq_type=M&A, top_tech=True, baseline_begin_period=10 quarters, threshold=90.
# ⚙️ Computing Mahalanobis: precomputed_mahalanobis_Off deal_bl_10q.pkl
# Precomputing Mahalanobis: 100%|██████████| 951/951 [00:17<00:00, 55.90it/s]
# ✅ Saved: precomputed_mahalanobis_Off deal_bl_10q.pkl
# Prepared and saved treated sample for acq_type=Off deal, top_tech=False, baseline_begin_period=10 quarters, threshold=None.
# ⚙️ Computing Mahalanobis: precomputed_mahalanobis_Off deal_top_tech_80_10q.pkl
# Precomputing Mahalanobis: 100%|██████████| 462/462 [00:10<00:00, 43.72it/s]
# ✅ Saved: precomputed_mahalanobis_Off deal_top_tech_80_10q.pkl
# ⚙️ Computing Mahalanobis: precomputed_mahalanobis_Off deal_top_tech_90_10q.pkl
# Precomputing Mahalanobis: 100%|██████████| 322/322 [00:07<00:00, 40.94it/s]
# ✅ Saved: precomputed_mahalanobis_Off deal_top_tech_90_10q.pkl
# Prepared and saved treated sample for acq_type=Off deal, top_tech=True, baseline_begin_period=10 quarters, threshold=90.
# Saved treated_counts_dict for baseline_begin_period=12 quarters.
# ⚙️ Computing Mahalanobis: precomputed_mahalanobis_M&A_bl_12q.pkl
# Precomputing Mahalanobis: 100%|██████████| 1451/1451 [00:36<00:00, 39.69it/s]
# ✅ Saved: precomputed_mahalanobis_M&A_bl_12q.pkl
# Prepared and saved treated sample for acq_type=M&A, top_tech=False, baseline_begin_period=12 quarters, threshold=None.
# ⚙️ Computing Mahalanobis: precomputed_mahalanobis_M&A_top_tech_80_12q.pkl
# Precomputing Mahalanobis: 100%|██████████| 649/649 [00:17<00:00, 37.31it/s]
# ✅ Saved: precomputed_mahalanobis_M&A_top_tech_80_12q.pkl
# ⚙️ Computing Mahalanobis: precomputed_mahalanobis_M&A_top_tech_90_12q.pkl
# Precomputing Mahalanobis: 100%|██████████| 423/423 [00:11<00:00, 35.42it/s]
# ✅ Saved: precomputed_mahalanobis_M&A_top_tech_90_12q.pkl
# Prepared and saved treated sample for acq_type=M&A, top_tech=True, baseline_begin_period=12 quarters, threshold=90.
# ⚙️ Computing Mahalanobis: precomputed_mahalanobis_Off deal_bl_12q.pkl
# Precomputing Mahalanobis: 100%|██████████| 919/919 [00:17<00:00, 51.56it/s]
# ✅ Saved: precomputed_mahalanobis_Off deal_bl_12q.pkl
# Prepared and saved treated sample for acq_type=Off deal, top_tech=False, baseline_begin_period=12 quarters, threshold=None.
# ⚙️ Computing Mahalanobis: precomputed_mahalanobis_Off deal_top_tech_80_12q.pkl
# Precomputing Mahalanobis: 100%|██████████| 488/488 [00:11<00:00, 42.68it/s]
# ✅ Saved: precomputed_mahalanobis_Off deal_top_tech_80_12q.pkl
# ⚙️ Computing Mahalanobis: precomputed_mahalanobis_Off deal_top_tech_90_12q.pkl
# Precomputing Mahalanobis: 100%|██████████| 310/310 [00:07<00:00, 39.25it/s]
# ✅ Saved: precomputed_mahalanobis_Off deal_top_tech_90_12q.pkl
# Prepared and saved treated sample for acq_type=Off deal, top_tech=True, baseline_begin_period=12 quarters, threshold=90.

# %% [markdown]
# # Run parallelized routine

# %%
import api.matching_cit as matching
import importlib
importlib.reload(matching)

# Run
matching.grid_runner_parallel_K(Ks = [10], max_workers = 3)
# Out:
# ⏭️ Skipping: M&A, baseline, 4q, caliper_0.0250, 10matches (results already exist)
# ⏭️ Skipping: M&A, baseline, 4q, caliper_0.0500, 10matches (results already exist)
# ⏭️ Skipping: M&A, baseline, 4q, caliper_0.0750, 10matches (results already exist)
# ⏭️ Skipping: M&A, baseline, 4q, caliper_0.1000, 10matches (results already exist)
# ⏭️ Skipping: M&A, top-tech, 80, 4q, caliper_0.0250, 10matches (results already exist)
# ⏭️ Skipping: M&A, top-tech, 80, 4q, caliper_0.0500, 10matches (results already exist)
# ⏭️ Skipping: M&A, top-tech, 80, 4q, caliper_0.0750, 10matches (results already exist)
# ⏭️ Skipping: M&A, top-tech, 80, 4q, caliper_0.1000, 10matches (results already exist)
# ⏭️ Skipping: M&A, top-tech, 90, 4q, caliper_0.0250, 10matches (results already exist)
# ⏭️ Skipping: M&A, top-tech, 90, 4q, caliper_0.0500, 10matches (results already exist)
# ⏭️ Skipping: M&A, top-tech, 90, 4q, caliper_0.0750, 10matches (results already exist)
# ⏭️ Skipping: M&A, top-tech, 90, 4q, caliper_0.1000, 10matches (results already exist)
# ⏭️ Skipping: Off deal, baseline, 4q, caliper_0.0250, 10matches (results already exist)
# ⏭️ Skipping: Off deal, baseline, 4q, caliper_0.0500, 10matches (results already exist)
# ⏭️ Skipping: Off deal, baseline, 4q, caliper_0.0750, 10matches (results already exist)
# ⏭️ Skipping: Off deal, baseline, 4q, caliper_0.1000, 10matches (results already exist)
# ⏭️ Skipping: Off deal, top-tech, 80, 4q, caliper_0.0250, 10matches (results already exist)
# ⏭️ Skipping: Off deal, top-tech, 80, 4q, caliper_0.0500, 10matches (results already exist)
# ⏭️ Skipping: Off deal, top-tech, 80, 4q, caliper_0.0750, 10matches (results already exist)
# ⏭️ Skipping: Off deal, top-tech, 80, 4q, caliper_0.1000, 10matches (results already exist)
# ⏭️ Skipping: Off deal, top-tech, 90, 4q, caliper_0.0250, 10matches (results already exist)
#
# 🔁 Launching 99 grid runs in parallel with 3 workers...
# Grid Jobs:   0%|          | 0/99 [00:00<?, ?it/s]
# [K=10 | Off deal, top_tech=True, threshold=90, caliper=0.05, baseline=4q][K=10 | Off deal, top_tech=True, threshold=90, caliper=0.075, baseline=4q][K=10 | Off deal, top_tech=True, threshold=90, caliper=0.1, baseline=4q]
# Grid Jobs:   0%|          | 0/99 [02:27<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /content/bert_for_patents/05 Analysis/01 Main/api/matching_cit.py in grid_runner_parallel_K(baseline_periods, calipers, acq_types, top_tech_flags, top_tech_thresholds, Ks, max_workers)
#     686         futures = [executor.submit(run_grid_point_K, t) for t in tasks]
# --> 687         for f in tqdm(as_completed(futures), total=len(futures), desc="Grid Jobs"):
#     688             try:
#
# /usr/local/lib/python3.11/dist-packages/tqdm/std.py in __iter__(self)
#    1180         try:
# -> 1181             for obj in iterable:
#    1182                 yield obj
#
# /usr/lib/python3.11/concurrent/futures/_base.py in as_completed(fs, timeout)
#     242
# --> 243             waiter.event.wait(wait_timeout)
#     244
#
# /usr/lib/python3.11/threading.py in wait(self, timeout)
#     628             if not signaled:
# --> 629                 signaled = self._cond.wait(timeout)
#     630             return signaled
#
# /usr/lib/python3.11/threading.py in wait(self, timeout)
#     326             if timeout is None:
# --> 327                 waiter.acquire()
#     328                 gotit = True
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-6-2685114012.py in <cell line: 0>()
#       4
#       5 # Run
# ----> 6 matching.grid_runner_parallel_K(Ks = [10], max_workers = 3)
#
# /content/bert_for_patents/05 Analysis/01 Main/api/matching_cit.py in grid_runner_parallel_K(baseline_periods, calipers, acq_types, top_tech_flags, top_tech_thresholds, Ks, max_workers)
#     683
#     684     results = []
# --> 685     with ProcessPoolExecutor(max_workers=max_workers) as executor:
#     686         futures = [executor.submit(run_grid_point_K, t) for t in tasks]
#     687         for f in tqdm(as_completed(futures), total=len(futures), desc="Grid Jobs"):
#
# /usr/lib/python3.11/concurrent/futures/_base.py in __exit__(self, exc_type, exc_val, exc_tb)
#     645
#     646     def __exit__(self, exc_type, exc_val, exc_tb):
# --> 647         self.shutdown(wait=True)
#     648         return False
#     649
#
# /usr/lib/python3.11/concurrent/futures/process.py in shutdown(self, wait, cancel_futures)
#     849
#     850         if self._executor_manager_thread is not None and wait:
# --> 851             self._executor_manager_thread.join()
#     852         # To reduce the risk of opening too many files, remove references to
#     853         # objects that use file descriptors.
#
# /usr/lib/python3.11/threading.py in join(self, timeout)
#    1117
#    1118         if timeout is None:
# -> 1119             self._wait_for_tstate_lock()
#    1120         else:
#    1121             # the behavior of a negative timeout isn't documented, but
#
# /usr/lib/python3.11/threading.py in _wait_for_tstate_lock(self, block, timeout)
#    1137
#    1138         try:
# -> 1139             if lock.acquire(block, timeout):
#    1140                 lock.release()
#    1141                 self._stop()
#
# KeyboardInterrupt:
