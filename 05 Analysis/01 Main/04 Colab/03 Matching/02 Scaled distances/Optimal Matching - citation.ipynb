# %% [markdown]
# # Drive and utilities

# %%
#@title Mount Drive to get BERT model
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
#@title Utils
# !pip install dill
# !pip install pandas
# !pip install numpy
!
import dill as pickle
# Out:
# Requirement already satisfied: dill in /usr/local/lib/python3.11/dist-packages (0.3.7)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (2.0.2)

# %%
#@title Clone the repo and add API key
# !git clone https://github.com/amusali/bert_for_patents.git
import os
# Api key setting
os.environ['patentsview_api_key'] = 'Uch9R1RR.BxaQcxV8HK4nBMgTTjX1F9CQW8PF4nXw'  # Replace with your actual key
# Out:
# Cloning into 'bert_for_patents'...
# remote: Enumerating objects: 1347, done.
# remote: Counting objects: 100% (19/19), done.
# remote: Compressing objects: 100% (13/13), done.
# remote: Total 1347 (delta 8), reused 13 (delta 6), pack-reused 1328 (from 1)
# Receiving objects: 100% (1347/1347), 180.75 MiB | 49.52 MiB/s, done.
# Resolving deltas: 100% (751/751), done.

# %%
#@title Run setup file to get environment
#!python "/content/bert_for_patents/05 Analysis/01 Main/setup_colab.py"

import sys
sys.path.append('/content/bert_for_patents/05 Analysis/01 Main')
os.chdir("/content/bert_for_patents/05 Analysis/01 Main")

# %%
#@title Pull latest changes from repo
# %cd "/content/bert_for_patents"
# !git pull origin master
#@title Add paths to the system and change directory
import sys
sys.path.append('/content/bert_for_patents/05 Analysis/01 Main')
os.chdir("/content/bert_for_patents/05 Analysis/01 Main")
# Out:
# /content/bert_for_patents
# From https://github.com/amusali/bert_for_patents
#  * branch            master     -> FETCH_HEAD
# Already up to date.

# %% [markdown]
# # Prepare

# %%
import api.matching_optimal_cit as matching
import importlib
importlib.reload(matching)

# Prepare
matching.prepare()
# Out:
# Loaded data: 145878465 citations, 19760 treated patents, 2876736 control patents, 2758562 clean ids.
# Preprocessed data: 44962852 citations, 19760 treated patents, 2758562 control patents.
# Precompute Cosine Distances: 100%|██████████| 1632/1632 [05:48<00:00,  4.68it/s]
# Saved treated_counts_dict for baseline_begin_period=9 quarters.
# ⚙️ Computing Mahalanobis: precomputed_mahalanobis_M&A_bl_9q.pkl
# Precomputing Mahalanobis: 100%|██████████| 1606/1606 [00:30<00:00, 52.74it/s]
# ✅ Saved: precomputed_mahalanobis_M&A_bl_9q.pkl
# Prepared and saved treated sample for acq_type=M&A, top_tech=False, baseline_begin_period=9 quarters, threshold=None.
# ⚙️ Computing Mahalanobis: precomputed_mahalanobis_M&A_top_tech_80_9q.pkl
# Precomputing Mahalanobis: 100%|██████████| 799/799 [00:14<00:00, 56.74it/s]
# ✅ Saved: precomputed_mahalanobis_M&A_top_tech_80_9q.pkl
# ⚙️ Computing Mahalanobis: precomputed_mahalanobis_M&A_top_tech_90_9q.pkl
# Precomputing Mahalanobis: 100%|██████████| 474/474 [00:08<00:00, 52.99it/s]
# ✅ Saved: precomputed_mahalanobis_M&A_top_tech_90_9q.pkl
# Prepared and saved treated sample for acq_type=M&A, top_tech=True, baseline_begin_period=9 quarters, threshold=90.
# ⚙️ Computing Mahalanobis: precomputed_mahalanobis_Off deal_bl_9q.pkl
# Precomputing Mahalanobis: 100%|██████████| 969/969 [00:12<00:00, 74.92it/s]
# ✅ Saved: precomputed_mahalanobis_Off deal_bl_9q.pkl
# Prepared and saved treated sample for acq_type=Off deal, top_tech=False, baseline_begin_period=9 quarters, threshold=None.
# ⚙️ Computing Mahalanobis: precomputed_mahalanobis_Off deal_top_tech_80_9q.pkl
# Precomputing Mahalanobis: 100%|██████████| 579/579 [00:09<00:00, 63.54it/s]
# ✅ Saved: precomputed_mahalanobis_Off deal_top_tech_80_9q.pkl
# ⚙️ Computing Mahalanobis: precomputed_mahalanobis_Off deal_top_tech_90_9q.pkl
# Precomputing Mahalanobis: 100%|██████████| 407/407 [00:06<00:00, 63.04it/s]
# ✅ Saved: precomputed_mahalanobis_Off deal_top_tech_90_9q.pkl
# Prepared and saved treated sample for acq_type=Off deal, top_tech=True, baseline_begin_period=9 quarters, threshold=90.
# Saved treated_counts_dict for baseline_begin_period=13 quarters.
# ⚙️ Computing Mahalanobis: precomputed_mahalanobis_M&A_bl_13q.pkl
# Precomputing Mahalanobis: 100%|██████████| 1409/1409 [00:25<00:00, 56.02it/s]
# ✅ Saved: precomputed_mahalanobis_M&A_bl_13q.pkl
# Prepared and saved treated sample for acq_type=M&A, top_tech=False, baseline_begin_period=13 quarters, threshold=None.
# ⚙️ Computing Mahalanobis: precomputed_mahalanobis_M&A_top_tech_80_13q.pkl
# Precomputing Mahalanobis: 100%|██████████| 681/681 [00:13<00:00, 51.77it/s]
# ✅ Saved: precomputed_mahalanobis_M&A_top_tech_80_13q.pkl
# ⚙️ Computing Mahalanobis: precomputed_mahalanobis_M&A_top_tech_90_13q.pkl
# Precomputing Mahalanobis: 100%|██████████| 438/438 [00:09<00:00, 48.21it/s]
# ✅ Saved: precomputed_mahalanobis_M&A_top_tech_90_13q.pkl
# Prepared and saved treated sample for acq_type=M&A, top_tech=True, baseline_begin_period=13 quarters, threshold=90.
# ⚙️ Computing Mahalanobis: precomputed_mahalanobis_Off deal_bl_13q.pkl
# Precomputing Mahalanobis: 100%|██████████| 895/895 [00:12<00:00, 69.13it/s]
# ✅ Saved: precomputed_mahalanobis_Off deal_bl_13q.pkl
# Prepared and saved treated sample for acq_type=Off deal, top_tech=False, baseline_begin_period=13 quarters, threshold=None.
# ⚙️ Computing Mahalanobis: precomputed_mahalanobis_Off deal_top_tech_80_13q.pkl
# Precomputing Mahalanobis: 100%|██████████| 463/463 [00:07<00:00, 60.23it/s]
# ✅ Saved: precomputed_mahalanobis_Off deal_top_tech_80_13q.pkl
# ⚙️ Computing Mahalanobis: precomputed_mahalanobis_Off deal_top_tech_90_13q.pkl
# Precomputing Mahalanobis: 100%|██████████| 357/357 [00:06<00:00, 57.41it/s]
# ✅ Saved: precomputed_mahalanobis_Off deal_top_tech_90_13q.pkl
# Prepared and saved treated sample for acq_type=Off deal, top_tech=True, baseline_begin_period=13 quarters, threshold=90.
# Saved treated_counts_dict for baseline_begin_period=17 quarters.
# ⚙️ Computing Mahalanobis: precomputed_mahalanobis_M&A_bl_17q.pkl
# Precomputing Mahalanobis: 100%|██████████| 1243/1243 [00:22<00:00, 54.47it/s]
# ✅ Saved: precomputed_mahalanobis_M&A_bl_17q.pkl
# Prepared and saved treated sample for acq_type=M&A, top_tech=False, baseline_begin_period=17 quarters, threshold=None.
# ⚙️ Computing Mahalanobis: precomputed_mahalanobis_M&A_top_tech_80_17q.pkl
# Precomputing Mahalanobis: 100%|██████████| 613/613 [00:12<00:00, 50.40it/s]
# ✅ Saved: precomputed_mahalanobis_M&A_top_tech_80_17q.pkl
# ⚙️ Computing Mahalanobis: precomputed_mahalanobis_M&A_top_tech_90_17q.pkl
# Precomputing Mahalanobis: 100%|██████████| 393/393 [00:08<00:00, 46.65it/s]
# ✅ Saved: precomputed_mahalanobis_M&A_top_tech_90_17q.pkl
# Prepared and saved treated sample for acq_type=M&A, top_tech=True, baseline_begin_period=17 quarters, threshold=90.
# ⚙️ Computing Mahalanobis: precomputed_mahalanobis_Off deal_bl_17q.pkl
# Precomputing Mahalanobis: 100%|██████████| 715/715 [00:10<00:00, 65.69it/s]
# ✅ Saved: precomputed_mahalanobis_Off deal_bl_17q.pkl
# Prepared and saved treated sample for acq_type=Off deal, top_tech=False, baseline_begin_period=17 quarters, threshold=None.
# ⚙️ Computing Mahalanobis: precomputed_mahalanobis_Off deal_top_tech_80_17q.pkl
# Precomputing Mahalanobis: 100%|██████████| 441/441 [00:07<00:00, 59.06it/s]
# ✅ Saved: precomputed_mahalanobis_Off deal_top_tech_80_17q.pkl
# ⚙️ Computing Mahalanobis: precomputed_mahalanobis_Off deal_top_tech_90_17q.pkl
# Precomputing Mahalanobis: 100%|██████████| 277/277 [00:04<00:00, 56.08it/s]
# ✅ Saved: precomputed_mahalanobis_Off deal_top_tech_90_17q.pkl
# Prepared and saved treated sample for acq_type=Off deal, top_tech=True, baseline_begin_period=17 quarters, threshold=90.

# %% [markdown]
# # Run parallelized routine

# %%
import api.matching_optimal_cit as matching
import importlib
importlib.reload(matching)

# Run
matching.grid_runner_parallel_K(Ks = [3, 5, 10], max_workers = 3)
# Out:
# /usr/local/lib/python3.11/dist-packages/cudf/utils/gpu_utils.py:75: UserWarning: Failed to dlopen libcuda.so.1
#   warnings.warn(str(e))
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-4-1563955247.py in <cell line: 0>()
# ----> 1 import api.matching_optimal_cit as matching
#
# /content/bert_for_patents/05 Analysis/01 Main/api/matching_optimal_cit.py in <module>
#       4 import numpy as np
#       5 import pandas as pd
# ----> 6 import cudf
#       7 import cupy as cp # Ensure cupy is installed with CUDA support
#       8 import torch
#
# /usr/local/lib/python3.11/dist-packages/cudf/__init__.py in <module>
#      30 from rmm.allocators.numba import RMMNumbaManager
#      31
# ---> 32 from cudf import api, core, datasets, testing
#      33 from cudf._version import __git_commit__, __version__
#      34 from cudf.api.extensions import (
#
# /usr/local/lib/python3.11/dist-packages/cudf/api/__init__.py in <module>
#       1 # Copyright (c) 2021, NVIDIA CORPORATION.
#       2
# ----> 3 from cudf.api import extensions, types
#       4
#       5 __all__ = ["extensions", "types"]
#
# /usr/local/lib/python3.11/dist-packages/cudf/api/extensions/__init__.py in <module>
#       3 from pandas.api.extensions import no_default
#       4
# ----> 5 from cudf.api.extensions.accessor import (
#       6     register_dataframe_accessor,
#       7     register_index_accessor,
#
# /usr/local/lib/python3.11/dist-packages/cudf/api/extensions/accessor.py in <module>
#       5 from pandas.core.accessor import CachedAccessor
#       6
# ----> 7 from cudf.core.dataframe import DataFrame
#       8 from cudf.core.index import Index
#       9 from cudf.core.series import Series
#
# /usr/local/lib/python3.11/dist-packages/cudf/core/dataframe.py in <module>
#      49     is_scalar,
#      50 )
# ---> 51 from cudf.core import indexing_utils, reshape
#      52 from cudf.core._compat import PANDAS_LT_300
#      53 from cudf.core.buffer import acquire_spill_lock
#
# /usr/local/lib/python3.11/dist-packages/cudf/core/reshape.py in <module>
#      15 from cudf.api.types import is_list_like, is_scalar
#      16 from cudf.core._compat import PANDAS_LT_300
# ---> 17 from cudf.core.column import (
#      18     ColumnBase,
#      19     as_column,
#
# /usr/local/lib/python3.11/dist-packages/cudf/core/column/__init__.py in <module>
#       1 # Copyright (c) 2020-2024, NVIDIA CORPORATION.
#       2
# ----> 3 from cudf.core.column.categorical import CategoricalColumn
#       4 from cudf.core.column.column import (
#       5     ColumnBase,
#
# /usr/local/lib/python3.11/dist-packages/cudf/core/column/categorical.py in <module>
#      16 import cudf
#      17 from cudf.api.types import is_scalar
# ---> 18 from cudf.core.column import column
#      19 from cudf.core.column.methods import ColumnMethods
#      20 from cudf.core.dtypes import CategoricalDtype, IntervalDtype
#
# /usr/local/lib/python3.11/dist-packages/cudf/core/column/column.py in <module>
#      31 )
#      32 from cudf.core._compat import PANDAS_GE_210
# ---> 33 from cudf.core._internals import (
#      34     aggregation,
#      35     copying,
#
# /usr/local/lib/python3.11/dist-packages/cudf/core/_internals/copying.py in <module>
#       6 import pylibcudf as plc
#       7
# ----> 8 from cudf.core.buffer import acquire_spill_lock
#       9
#      10 if TYPE_CHECKING:
#
# /usr/local/lib/python3.11/dist-packages/cudf/core/buffer/__init__.py in <module>
#       1 # Copyright (c) 2022-2024, NVIDIA CORPORATION.
#       2
# ----> 3 from cudf.core.buffer.buffer import (
#       4     Buffer,
#       5     BufferOwner,
#
# KeyboardInterrupt:
