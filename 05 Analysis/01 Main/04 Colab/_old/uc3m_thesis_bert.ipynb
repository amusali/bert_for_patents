# %%
## Clone repo for analysis
from getpass import getpass
import os

# Store your personal access token securely
token = getpass('Enter your GitHub personal access token: ')

# Clone the private repository
# !git clone https://{token}@github.com/amusali/bert_for_patents
# Out:
# Enter your GitHub personal access token: ··········
# fatal: destination path 'bert_for_patents' already exists and is not an empty directory.

# %%
# %cd /content/bert_for_patents
# Out:
# /content/bert_for_patents

# %%
import api.fetch_patents as fp
import importlib
importlib.reload(fp)
from datetime import datetime, timedelta
import pandas as pd
import re

date = "2008-12-12"
#date = datetime.strptime(date, "%Y-%m-%d")
print(date)
x = fp.get_patents('FACEBOOK, INC.', date, source = 'legacy')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-5-2e8efcb12837> in <cell line: 1>()
# ----> 1 import api.fetch_patents as fp
#       2 import importlib
#       3 importlib.reload(fp)
#       4 from datetime import datetime, timedelta
#       5 import pandas as pd
#
# ModuleNotFoundError: No module named 'api'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
